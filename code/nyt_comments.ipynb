# %% [markdown]
# # NYT Comment Analysis
# * Build csv file of comments from NYT articles:
#     * Read raw bytes object from NYT API
#     * Convert to json object(s)
#     * Extract data to csv format

# %%
# Modules
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import pandas as pd
import json
import math
import numpy as np
import scipy as sp
from scipy import stats
from scipy.stats import pearsonr

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as col
import matplotlib.cm as cm
import seaborn as sns; sns.set()
from datetime import datetime

from collections import Counter
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen
import requests
import urllib3
import zipfile
import re
import glob
import os
import time

# Pandas view options
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('precision', 4)

# %% [markdown]
# ## Program Parameters

# %%
# File paths (Change BASE_PATH to your project folder)
BASE_PATH = '/Users/apelullo/Desktop/CDH/projects/nyt/data/'
URL_PATH = BASE_PATH + 'urls/'
MASTER_PATH = BASE_PATH + 'master_data/'

# API credentials (keys are from 9 distinct APPS)
API_REQUEST = 'https://api.nytimes.com/svc/community/v3/user-content/url.json?api-key='
KEYS = ['REDACTED','REDACTED','REDACTED',
        'REDACTED','REDACTED','REDACTED',
        'REDACTED','REDACTED','REDACTED']

# Constants
DEFAULT_SLEEP = 6
TIMEOUT_SLEEP = 10
MAX_ATTEMPT = 10

# %% [markdown]
# ## Functions

# %%
def get_response(url,num_requests,curr_key,offset,complete):
    timeout = 0
    processed = False
    
    # Build request url
    if num_requests%10==0:
        curr_key = (curr_key+1)%len(KEYS)
        print('Switching keys: ' + KEYS[curr_key][0:10] + '...')
    request_url = API_REQUEST + KEYS[curr_key] + '&offset=' + str(offset) + '&url=http://' + url

    # Request handling: status codes 200,400,429
    while not processed:
        response = requests.get(request_url)
        status = response.status_code
        num_requests+=1
        time.sleep(DEFAULT_SLEEP)
        
        if status==200:
            # Check for empty response content
            content = soup(response.content)
            if len(content)==0:
                return None,num_requests,curr_key,offset,complete

            # Convert to json
            json_content = json.loads(content.text)
            results = json_content['results']

            # Pagination
            returned_comments = results['totalParentCommentsReturned']
            offset += returned_comments
            
            # Check for completion
            if returned_comments < 25:
                complete=True

            processed=True
            print('Request successful!',returned_comments,'top-level comments returned...')
        elif status==400:
            results=None
            processed=True
            print('Bad request! Error code:', status)
        elif status==429:
            timeout+=1
            print('Rate limit exceeded! Error code:', status)
            if timeout < MAX_ATTEMPT:
                print('Sleeping for',TIMEOUT_SLEEP,'seconds and retrying...')
                time.sleep(TIMEOUT_SLEEP)
            else:
                results=None
                processed=True
                print('Too many attempts!')
        else:
            results=None
            processed=True
            print('There was an error executing the request! Error code:', status)
    
    return results,num_requests,curr_key,offset,complete

# %%
def get_article_meta(results,article_id):
    article_row = []
    article_cols = [item for item in list(results.keys()) if item not in ['comments','userData']]
    
    # Build article row
    for col in article_cols:
        article_row.append(results[col])
    
    # Add article_id
    article_row.append(article_id)
    article_cols.append('article_id')
    return article_row, article_cols

# %%
def get_comments(comments,article_id):
    comment_chunk = []
    
    # Iterate through comment chunk
    for com in comments:
        comment_row = []
        comment_cols = [item for item in list(com.keys()) if item not in ['replies']]

        # Build comment row
        for col in comment_cols:
            comment_row.append(com[col])
        
        # Add article_id
        comment_row.append(article_id)
        comment_cols.append('article_id')
        
        # Add comment row to comment chunk
        comment_chunk.append(comment_row)
        
        # Handle replies recursively
        replies = com['replies']
        if len(replies) != 0:
            # Add replies to comment chunk
            print('Collecting comment replies...')
            reply_data,reply_cols = get_comments(replies,article_id)
            comment_chunk = comment_chunk + reply_data
        
    return comment_chunk,comment_cols

# %%
def process_urls(url_list):
    article_data = []
    comment_data = []

    article_id = 0
    num_requests = 1
    curr_key = 0

    offset = 0
    first = True
    complete = False

    for url in url_list:
        print('\nProcessing url:', url)
        print('Article id:', article_id)
        while not complete:
            # Get response
            print('Executing Request...')
            results,num_requests,curr_key,offset,complete = get_response(url,num_requests,curr_key,offset,complete)
            
            # Check for empty results
            if results==None:
                print('Article does not exist! Moving on..')
                break

            # Article metadata
            if first:
                print('Collecting article metadata...')
                article_meta,article_cols = get_article_meta(results,article_id)
                article_data.append(article_meta)
                first=False
                
            # Check for empty comments
            returned_comments = results['totalParentCommentsReturned']
            if returned_comments==0:
                print('Article has no comments! Moving on..')
                break

            # Comments and replies
            print('Collecting article comments...')
            comments = results['comments']
            comment_chunk,comment_cols = get_comments(comments,article_id)
            if len(comment_data)==0:
                comment_data = comment_chunk
            else:
                comment_data = comment_data + comment_chunk

            print(str(len(comment_data)) + ' comments and replies extracted.')

        # Reset parameters
        article_id += 1
        offset=0
        first=True
        complete=False
    
    print('All articles processed correctly! Our work here is done - See you next time!')
    return [[article_data,article_cols],[comment_data,comment_cols]]

# %% [markdown]
# ## Read Data

# %%
# open files if they exist
if os.path.exists(URL_PATH + 'privacy_urls.csv') and os.path.exists(URL_PATH + 'health_urls.csv'):
    print('Reading from file.')
    privacy_urls = pd.read_csv(URL_PATH + 'privacy_urls.csv')
    health_urls = pd.read_csv(URL_PATH + 'health_urls.csv')
else:
    print('Creating url lists.')
    with open(URL_PATH + 'privacy_urls_raw.txt') as file:
        contents = file.read()
        temp = contents.split('href="https://')[1:]
        urls = [item.split('">\\\n')[0] for item in temp]

        # all privacy articles
        privacy_urls = pd.DataFrame(urls, columns=['url'])
        privacy_urls.to_csv(URL_PATH + 'privacy_urls.csv', index=False)

        # health articles
        health_urls = privacy_urls.iloc[[45,90],:]
        health_urls.to_csv(URL_PATH + 'health_urls.csv', index=False)
# Out:
# Reading from file.

# %% [markdown]
# ## Main Program

# %%
output = dict()
#url_dict={'health_urls':list(health_urls.url)}
url_dict={'privacy_urls':list(privacy_urls.url)}
#url_dict={'health_urls':list(health_urls.url),'privacy_urls':list(privacy_urls.url)}

for key,urls in url_dict.items():
    output[key] = process_urls(urls)
# Out:
# Processing url: www.nytimes.com/2019/07/25/opinion/facebook-fine-5-billion.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 0
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 38 comments and replies extracted.
# Executing Request...
# Request successful! 12 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 57 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/23/opinion/google-ftc-facebook-fines.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 1
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/07/20/opinion/sunday/the-spy-business-is-booming-and-we-should-be-worried.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 2
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/07/19/opinion/private-surveillance-industry.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 3
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 95 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 136 comments and replies extracted.
# Executing Request...
# Request successful! 2 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 141 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/18/opinion/faceapp-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 4
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 169 comments and replies extracted.
# Executing Request...
# Request successful! 7 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 184 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/17/opinion/google-facebook-sex-websites.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 5
# Executing Request...
# Switching keys: ErlMB7lQkc...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 217 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 250 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 283 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 320 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 370 comments and replies extracted.
# Executing Request...
# Request successful! 13 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 398 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/16/opinion/privacy-project-nytimes.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 6
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/07/15/opinion/intel-data-brokers.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 7
# Executing Request...
# Article does not exist! Moving on..
#
# Processing url: www.nytimes.com/2019/07/14/opinion/kevin-mccarthy-privacy-blockchain.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 8
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# 423 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# 449 comments and replies extracted.
# Executing Request...
# Switching keys: 7adp5kTspN...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# 475 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 506 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 539 comments and replies extracted.
# Executing Request...
# Request successful! 6 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 549 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/11/opinion/data-humanitarian-aid.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 9
# Executing Request...
# Request successful! 19 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 574 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/10/opinion/facial-recognition-race.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 10
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 609 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 649 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 691 comments and replies extracted.
# Executing Request...
# Request successful! 4 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 700 comments and replies extracted.
#
# Processing url: www.nytimes.com/interactive/2019/07/10/opinion/google-privacy-policy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 11
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# 726 comments and replies extracted.
# Executing Request...
# Switching keys: eIek4ocPuF...
# Request successful! 6 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 745 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/09/opinion/love-island-usa.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 12
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# 770 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 801 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 841 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 877 comments and replies extracted.
# Executing Request...
# Request successful! 15 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 909 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/07/opinion/google-ads.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 13
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 949 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 978 comments and replies extracted.
# Executing Request...
# Request successful! 10 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 999 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/07/05/opinion/health-data-property-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 14
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/07/02/opinion/surveillance-state-schools.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 15
# Executing Request...
# Switching keys: uqpjc4N8kA...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/07/01/opinion/slack-chat-hackers-encryption.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 16
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1034 comments and replies extracted.
# Executing Request...
# Request successful! 12 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1056 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/30/opinion/immigrants-social-media.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 17
# Executing Request...
# Request successful! 10 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1070 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/29/opinion/sunday/conficker-worm-ukraine.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 18
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1106 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1153 comments and replies extracted.
# Executing Request...
# Request successful! 10 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1176 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/27/opinion/cities-privacy-surveillance.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 19
# Executing Request...
# Request successful! 19 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1202 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/27/opinion/police-cam-facial-recognition.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 20
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1236 comments and replies extracted.
# Executing Request...
# Request successful! 4 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 1243 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/25/opinion/congress-privacy-law.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 21
# Executing Request...
# Switching keys: MGDqrMfUG9...
# Request successful! 16 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 1261 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/25/opinion/congress-privacy-bill-internet.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 22
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/06/20/opinion/queer-dating-apps.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 23
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 1290 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1334 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1383 comments and replies extracted.
# Executing Request...
# Request successful! 1 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# 1387 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/19/opinion/facebook-currency-libra.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 24
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/06/19/opinion/facebook-google-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 25
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1421 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1466 comments and replies extracted.
# Executing Request...
# Request successful! 10 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1491 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/18/opinion/facebook-court-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 26
# Executing Request...
# Switching keys: wx1wBxJXkl...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/interactive/2019/06/14/opinion/bluetooth-wireless-tracking-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 27
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 1518 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1556 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1586 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1620 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1659 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1697 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1752 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1808 comments and replies extracted.
# Executing Request...
# Request successful! 5 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1820 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/13/opinion/timothy-carpenter-prison-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 28
# Executing Request...
# Switching keys: 27A0h9dxWJ...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/06/13/opinion/privacy-law-enforcment-congress.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 29
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1856 comments and replies extracted.
# Executing Request...
# Request successful! 9 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1875 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/11/opinion/privacy-facebook-sexting.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 30
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/06/11/opinion/police-dna-warrant.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 31
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1910 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1954 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 1991 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2041 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2091 comments and replies extracted.
# Executing Request...
# Request successful! 20 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2138 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/10/opinion/hacking-phone-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 32
# Executing Request...
# Switching keys: sMMkdHR7PD...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 2166 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2203 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2241 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2282 comments and replies extracted.
# Executing Request...
# Request successful! 13 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2302 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/09/opinion/facial-recognition-police-new-york-city.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 33
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# 2327 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2360 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2391 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2421 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2457 comments and replies extracted.
# Executing Request...
# Switching keys: 96zqzbAAur...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2492 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2552 comments and replies extracted.
# Executing Request...
# Request successful! 2 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 2560 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/08/opinion/sunday/privacy-congress-facebook-google.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 34
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/06/07/opinion/lockport-facial-recognition-schools.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 35
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2591 comments and replies extracted.
# Executing Request...
# Request successful! 17 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2616 comments and replies extracted.
#
# Processing url: www.nytimes.com/interactive/2019/06/07/opinion/google-facebook-mergers-acquisitions-antitrust.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 36
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 2646 comments and replies extracted.
# Executing Request...
# Request successful! 17 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2668 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/05/opinion/children-internet-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 37
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2702 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2751 comments and replies extracted.
# Executing Request...
# Switching keys: ErlMB7lQkc...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2793 comments and replies extracted.
# Executing Request...
# Request successful! 17 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2827 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/04/opinion/google-purchases.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 38
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/06/03/opinion/google-facebook-data-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 39
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2860 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2896 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2938 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 2978 comments and replies extracted.
# Executing Request...
# Request successful! 20 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3017 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/06/01/opinion/surveillance-cameras-work.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 40
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/05/30/opinion/hate-speech-law-singapore.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 41
# Executing Request...
# Request successful! 16 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3039 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/05/28/opinion/online-ads.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 42
# Executing Request...
# Switching keys: 7adp5kTspN...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/05/28/opinion/privacy-antitrust-facebook.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 43
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3077 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3119 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3149 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3200 comments and replies extracted.
# Executing Request...
# Request successful! 0 top-level comments returned...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/05/23/opinion/privacy-tech-companies.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 44
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3228 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3257 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3294 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# 3320 comments and replies extracted.
# Executing Request...
# Switching keys: eIek4ocPuF...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# 3345 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# 3370 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# 3395 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 3422 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 3449 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3483 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 3512 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3544 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3591 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 3621 comments and replies extracted.
# Executing Request...
# Switching keys: uqpjc4N8kA...
# Request successful! 19 top-level comments returned...
# Collecting article comments...
# ...
# Collecting comment replies...
# 10144 comments and replies extracted.
# Executing Request...
# Request successful! 22 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10193 comments and replies extracted.
#
# Processing url: www.nytimes.com/interactive/2019/04/10/opinion/tech-companies-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 87
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10223 comments and replies extracted.
# Executing Request...
# Request successful! 23 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10255 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/04/10/opinion/sunday/privacy-capitalism.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 88
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10285 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10314 comments and replies extracted.
# Executing Request...
# Switching keys: sMMkdHR7PD...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 10342 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# 10367 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10406 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10444 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10488 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10532 comments and replies extracted.
# Executing Request...
# Request successful! 1 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# 10534 comments and replies extracted.
#
# Processing url: www.nytimes.com/interactive/2019/04/10/opinion/privacy-survey.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 89
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# 10560 comments and replies extracted.
# Executing Request...
# Request successful! 0 top-level comments returned...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/04/10/opinion/insurance-ai.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 90
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10591 comments and replies extracted.
# Executing Request...
# Switching keys: 96zqzbAAur...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# 10616 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# 10642 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10674 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10710 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# 10739 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10784 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10822 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10861 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10905 comments and replies extracted.
# Executing Request...
# Request successful! 16 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10945 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/04/10/opinion/privacy-feminism.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 91
# Executing Request...
# Switching keys: ErlMB7lQkc...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 10992 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11027 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11069 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11107 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11141 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11193 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11254 comments and replies extracted.
# Executing Request...
# Request successful! 5 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11268 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/04/10/opinion/genetic-testing-privacy.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 92
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/2019/04/10/opinion/sunday/privacy-religion.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 93
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article metadata...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11316 comments and replies extracted.
# Executing Request...
# Switching keys: 7adp5kTspN...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11363 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11415 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11461 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11491 comments and replies extracted.
# Executing Request...
# Request successful! 25 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11546 comments and replies extracted.
# Executing Request...
# Request successful! 3 top-level comments returned...
# Collecting article comments...
# Collecting comment replies...
# Collecting comment replies...
# Collecting comment replies...
# 11555 comments and replies extracted.
#
# Processing url: www.nytimes.com/2019/04/10/opinion/internet-privacy-resources.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 94
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
#
# Processing url: www.nytimes.com/interactive/2019/04/10/opinion/internet-privacy-terms.html?rref=collection%2Fseriescollection%2Fnew-york-times-privacy-project
# Article id: 95
# Executing Request...
# Request successful! 0 top-level comments returned...
# Collecting article metadata...
# Article has no comments! Moving on..
# All articles processed correctly! Our work here is done - See you next time!

# %%
# NOTE: Threading/multiprocessing will work well here, assuming independent rate limits for keys from distinct apps

# %% [markdown]
# ## Explore Data

# %% [markdown]
# ### Create Dataframes and Save

# %%
# Create dataframes
health_article_df = pd.DataFrame(output['health_urls'][0][0], columns=output['health_urls'][0][1])
health_article_df.to_csv(MASTER_PATH + 'health_article_data.csv', index=False)

health_comment_df = pd.DataFrame(output['health_urls'][1][0], columns=output['health_urls'][1][1])
health_comment_df.to_csv(MASTER_PATH + 'health_comment_data.csv', index=False)

# %%
# Create dataframes
privacy_article_df = pd.DataFrame(output['privacy_urls'][0][0], columns=output['privacy_urls'][0][1])
privacy_article_df.to_csv(MASTER_PATH + 'privacy_article_data.csv', index=False)

privacy_comment_df = pd.DataFrame(output['privacy_urls'][1][0], columns=output['privacy_urls'][1][1])
privacy_comment_df.to_csv(MASTER_PATH + 'privacy_comment_data.csv', index=False)

# %% [markdown]
# ### Health Data

# %%
print(len(health_article_df))
print(len(health_article_df.columns))
health_article_df.head()
# Out:
# 2
# 20
#   callerID api_timestamp  depthLimit filter  page  replyLimit sort  \
# 0     None    1564206858           2            1           3
# 1     None    1564206899           2            1           3
#
#    totalCommentsFound  totalCommentsReturned  totalEditorsSelectionFound  \
# 0                 200                     26                           7
# 1                 451                     31                          14
#
#    totalEditorsSelectionReturned  totalParentCommentsFound  \
# 0                              0                       162
# 1                              2                       266
#
#    totalParentCommentsReturned  totalRecommendationsFound  \
# 0                           25                        144
# 1                           25                        291
#
#    totalRecommendationsReturned  totalReplyCommentsFound  \
# 0                            13                       38
# 1                            15                      185
#
#    totalReplyCommentsReturned  totalReporterReplyCommentsFound  \
# 0                           1                                0
# 1                           6                                0
#
#    totalReporterReplyCommentsReturned  article_id
# 0                                   0           0
# 1                                   0           1

# %%
print(len(health_comment_df))
print(len(health_comment_df.columns))
health_comment_df.head(2)
# Out:
# 581
# 26
#    commentID    status  commentSequence  userID userDisplayName  \
# 0  100725114  approved        100725114       0     Anne Fauvre
# 1  100675020  approved        100675020       0         michael
#
#     userLocation userTitle userURL picURL commentTitle  \
# 0  San Francisco      NULL    NULL   None      <br\//>
# 1       tristate      NULL    NULL   None      <br\//>
#
#                                          commentBody  createDate  updateDate  \
# 0  With new technologies I don't think this has t...  1559246362  1559250380
# 1  Tsk, tsk, tsk.\n\nWhy don't you work on implem...  1558986958  1559061711
#
#   approveDate  recommendations  replyCount  editorsSelection  parentID  \
# 0  1559246436                1           0             False       NaN
# 1  1559061711                0           0             False       NaN
#
#   parentUserDisplayName  depth commentType  trusted  recommendedFlag  \
# 0                  None      1     comment        0                0
# 1                  None      1     comment        0                0
#
#       permID  isAnonymous  article_id
# 0  100725114        False           0
# 1  100675020        False           0

# %%
# Summary stats
print('Total unique articles:', len(health_comment_df.article_id.unique()))
print()
print('Total unique comments and replies:', len(health_comment_df.commentID.unique()))
for idx in health_comment_df.article_id.unique():
    print('\tArticle ' + str(idx) + ':', len(health_comment_df[health_comment_df['article_id']==idx]))
print()
print('Total unique comments:', len(health_comment_df[health_comment_df['parentID'].isnull()]))
for idx in health_comment_df.article_id.unique():
    print('\tArticle ' + str(idx) + ':', len(health_comment_df[(health_comment_df['article_id']==idx)&(health_comment_df['parentID'].isnull())]))
print()
print('Total unique replies:', len(health_comment_df[health_comment_df['parentID'].notnull()]))
for idx in health_comment_df.article_id.unique():
    print('\tArticle ' + str(idx) + ':', len(health_comment_df[(health_comment_df['article_id']==idx)&(health_comment_df['parentID'].notnull())]))
# Out:
# Total unique articles: 2
#
# Total unique comments and replies: 581
# 	Article 0: 196
# 	Article 1: 385
#
# Total unique comments: 428
# 	Article 0: 162
# 	Article 1: 266
#
# Total unique replies: 153
# 	Article 0: 34
# 	Article 1: 119

# %%
# What else would be interesting to summarize?

# %%
# The possibilities are endless... =)

# %% [markdown]
# ### Privacy Data

# %%
print(len(privacy_article_df))
print(len(privacy_article_df.columns))
privacy_article_df.head()
# Out:
# 94
# 20
#   callerID api_timestamp  depthLimit filter  page  replyLimit sort  \
# 0     None    1564242487           2            1           3
# 1     None    1564242501           2            0           3
# 2     None    1564242507           2            0           3
# 3     None    1564242513           2            1           3
# 4     None    1564242533           2            1           3
#
#    totalCommentsFound  totalCommentsReturned  totalEditorsSelectionFound  \
# 0                  59                     38                           3
# 1                   0                      0                           0
# 2                   0                      0                           0
# 3                  86                     38                           0
# 4                  43                     28                           0
#
#    totalEditorsSelectionReturned  totalParentCommentsFound  \
# 0                              3                        37
# 1                              0                         0
# 2                              0                         0
# 3                              0                        52
# 4                              0                        32
#
#    totalParentCommentsReturned  totalRecommendationsFound  \
# 0                           25                         13
# 1                            0                          0
# 2                            0                          0
# 3                           25                         69
# 4                           25                         21
#
#    totalRecommendationsReturned  totalReplyCommentsFound  \
# 0                             7                       22
# 1                             0                        0
# 2                             0                        0
# 3                            31                       34
# 4                            11                       11
#
#    totalReplyCommentsReturned  totalReporterReplyCommentsFound  \
# 0                          13                                0
# 1                           0                                0
# 2                           0                                0
# 3                          13                                0
# 4                           3                                0
#
#    totalReporterReplyCommentsReturned  article_id
# 0                                   0           0
# 1                                   0           1
# 2                                   0           2
# 3                                   0           3
# 4                                   0           4

# %%
print(len(privacy_comment_df))
print(len(privacy_comment_df.columns))
privacy_comment_df.head(2)
# Out:
# 11555
# 26
#    commentID    status  commentSequence  userID userDisplayName userLocation  \
# 0  101672372  approved        101672372       0             JRB         KCMO
# 1  101677421  approved        101677421       0            Matt     Montreal
#
#   userTitle userURL picURL commentTitle  \
# 0      NULL    NULL   None      <br\//>
# 1      NULL    NULL   None      <br\//>
#
#                                          commentBody  createDate  updateDate  \
# 0  $5 billion? Hey, somebody go over there and ge...  1564179032  1564230824
# 1  I was one of the  80 million of Anthem Blue Cr...  1564224235  1564229710
#
#   approveDate  recommendations  replyCount  editorsSelection  parentID  \
# 0  1564230824                0           0             False       NaN
# 1  1564229710                0           0             False       NaN
#
#   parentUserDisplayName  depth commentType  trusted  recommendedFlag  \
# 0                  None      1     comment        0                0
# 1                  None      1     comment        0                0
#
#       permID  isAnonymous  article_id
# 0  101672372        False           0
# 1  101677421        False           0

# %%
# Summary stats
print('Total unique articles:', len(privacy_comment_df.article_id.unique()))
print()
print('Total unique comments and replies:', len(privacy_comment_df.commentID.unique()))
for idx in privacy_comment_df.article_id.unique():
    print('\tArticle ' + str(idx) + ':', len(privacy_comment_df[privacy_comment_df['article_id']==idx]))
print()
print('Total unique comments:', len(privacy_comment_df[privacy_comment_df['parentID'].isnull()]))
for idx in privacy_comment_df.article_id.unique():
    print('\tArticle ' + str(idx) + ':', len(privacy_comment_df[(privacy_comment_df['article_id']==idx)&(privacy_comment_df['parentID'].isnull())]))
print()
print('Total unique replies:', len(privacy_comment_df[privacy_comment_df['parentID'].notnull()]))
for idx in privacy_comment_df.article_id.unique():
    print('\tArticle ' + str(idx) + ':', len(privacy_comment_df[(privacy_comment_df['article_id']==idx)&(privacy_comment_df['parentID'].notnull())]))
# Out:
# Total unique articles: 68
#
# Total unique comments and replies: 11555
# 	Article 0: 57
# 	Article 3: 84
# 	Article 4: 43
# 	Article 5: 214
# 	Article 8: 151
# 	Article 9: 25
# 	Article 10: 126
# 	Article 11: 45
# 	Article 12: 164
# 	Article 13: 90
# 	Article 16: 57
# 	Article 17: 14
# 	Article 18: 106
# 	Article 19: 26
# 	Article 20: 41
# 	Article 21: 18
# 	Article 23: 126
# 	Article 25: 104
# 	Article 27: 329
# 	Article 29: 55
# 	Article 31: 263
# 	Article 32: 164
# 	Article 33: 258
# 	Article 35: 56
# 	Article 36: 52
# 	Article 37: 159
# 	Article 39: 190
# 	Article 41: 22
# 	Article 43: 161
# 	Article 44: 448
# 	Article 45: 196
# 	Article 46: 215
# 	Article 48: 217
# 	Article 49: 65
# 	Article 50: 67
# 	Article 51: 203
# 	Article 52: 176
# 	Article 53: 67
# 	Article 54: 61
# 	Article 55: 118
# 	Article 56: 29
# 	Article 57: 207
# 	Article 58: 911
# 	Article 59: 270
# 	Article 61: 102
# 	Article 63: 176
# 	Article 65: 234
# 	Article 67: 143
# 	Article 68: 104
# 	Article 70: 283
# 	Article 71: 100
# 	Article 73: 200
# 	Article 74: 311
# 	Article 75: 126
# 	Article 77: 125
# 	Article 78: 463
# 	Article 79: 164
# 	Article 80: 25
# 	Article 81: 252
# 	Article 84: 424
# 	Article 85: 268
# 	Article 86: 243
# 	Article 87: 62
# 	Article 88: 279
# 	Article 89: 26
# 	Article 90: 385
# 	Article 91: 323
# 	Article 93: 287
#
# Total unique comments: 7968
# 	Article 0: 37
# 	Article 3: 52
# 	Article 4: 32
# 	Article 5: 138
# 	Article 8: 131
# 	Article 9: 19
# 	Article 10: 79
# 	Article 11: 31
# 	Article 12: 115
# 	Article 13: 60
# 	Article 16: 37
# 	Article 17: 10
# 	Article 18: 60
# 	Article 19: 19
# 	Article 20: 29
# 	Article 21: 16
# 	Article 23: 76
# 	Article 25: 60
# 	Article 27: 205
# 	Article 29: 34
# 	Article 31: 145
# 	Article 32: 113
# 	Article 33: 177
# 	Article 35: 42
# 	Article 36: 42
# 	Article 37: 92
# 	Article 39: 120
# 	Article 41: 16
# 	Article 43: 100
# 	Article 44: 369
# 	Article 45: 162
# 	Article 46: 154
# 	Article 48: 170
# 	Article 49: 50
# 	Article 50: 49
# 	Article 51: 147
# 	Article 52: 123
# 	Article 53: 52
# 	Article 54: 37
# 	Article 55: 81
# 	Article 56: 25
# 	Article 57: 125
# 	Article 58: 729
# 	Article 59: 198
# 	Article 61: 64
# 	Article 63: 126
# 	Article 65: 151
# 	Article 67: 109
# 	Article 68: 72
# 	Article 70: 235
# 	Article 71: 56
# 	Article 73: 117
# 	Article 74: 182
# 	Article 75: 93
# 	Article 77: 87
# 	Article 78: 306
# 	Article 79: 109
# 	Article 80: 25
# 	Article 81: 176
# 	Article 84: 303
# 	Article 85: 179
# 	Article 86: 147
# 	Article 87: 48
# 	Article 88: 201
# 	Article 89: 25
# 	Article 90: 266
# 	Article 91: 180
# 	Article 93: 153
#
# Total unique replies: 3587
# 	Article 0: 20
# 	Article 3: 32
# 	Article 4: 11
# 	Article 5: 76
# 	Article 8: 20
# 	Article 9: 6
# 	Article 10: 47
# 	Article 11: 14
# 	Article 12: 49
# 	Article 13: 30
# 	Article 16: 20
# 	Article 17: 4
# 	Article 18: 46
# 	Article 19: 7
# 	Article 20: 12
# 	Article 21: 2
# 	Article 23: 50
# 	Article 25: 44
# 	Article 27: 124
# 	Article 29: 21
# 	Article 31: 118
# 	Article 32: 51
# 	Article 33: 81
# 	Article 35: 14
# 	Article 36: 10
# 	Article 37: 67
# 	Article 39: 70
# 	Article 41: 6
# 	Article 43: 61
# 	Article 44: 79
# 	Article 45: 34
# 	Article 46: 61
# 	Article 48: 47
# 	Article 49: 15
# 	Article 50: 18
# 	Article 51: 56
# 	Article 52: 53
# 	Article 53: 15
# 	Article 54: 24
# 	Article 55: 37
# 	Article 56: 4
# 	Article 57: 82
# 	Article 58: 182
# 	Article 59: 72
# 	Article 61: 38
# 	Article 63: 50
# 	Article 65: 83
# 	Article 67: 34
# 	Article 68: 32
# 	Article 70: 48
# 	Article 71: 44
# 	Article 73: 83
# 	Article 74: 129
# 	Article 75: 33
# 	Article 77: 38
# 	Article 78: 157
# 	Article 79: 55
# 	Article 80: 0
# 	Article 81: 76
# 	Article 84: 121
# 	Article 85: 89
# 	Article 86: 96
# 	Article 87: 14
# 	Article 88: 78
# 	Article 89: 1
# 	Article 90: 119
# 	Article 91: 143
# 	Article 93: 134

# %% [markdown]
# ## Unused / Deprecated Code
